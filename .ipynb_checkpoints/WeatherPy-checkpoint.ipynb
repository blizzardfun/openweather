# %%
#%matplotlib notebook
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from datetime import date
import openweathermapy.core as owm
# Import API key
from api_keys import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"
# Output files (PNG)
temp_file="output_data/temp_graph.png"
humidity_file="output_data/humidity_graph.png"
cloud_file="output_data/cloud_graph.png"
wind_file="output_data/wind_graph.png"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)
#date for labeling graphs
today=str(date.today())

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 611

# %% [markdown]
# ## Perform API Calls

# %%
# OpenWeatherMap url = "http://api.openweathermap.org/data/2.5/weather?"
# Create settings dictionary with information we're interested in
settings = {"units": "metric", "appid": api_key}
summary=["name","id","coord.lat","wind.speed","main.temp","main.humidity","clouds.all"]

# %%
summary_data=[]
for city in cities:
    try:
        current_weather=owm.get_current(city, **settings)
        city_data=current_weather(*summary)
        summary_data.append(city_data)
        print(f"Processing {current_weather['name']} with id {current_weather['id']} ")        
    except:
        print(f"{city} not found")

#convert to dataframe and name columns        
summary_df=pd.DataFrame(summary_data)
summary_df=summary_df.rename(columns={0:"name",1:"id",2:"lat",3:"windspeed",4:"temp",5:"humidity",6:"cloudiness"})
#save to file
summary_df.to_csv(output_data_file,index=False,header=True)
#confirm sufficient count after cities found
summary_df.count()
# Out:
# Processing North Bend with id 5742974
# Processing Puerto Suarez with id 3465342
# Processing Port Keats with id 2063039
# Processing Dikson with id 1507390
# Processing Bethel with id 5880568
# bengkulu not found
# Processing Bambous Virieux with id 1106677
# Processing Markala with id 2453662
# Processing Tecoanapa with id 3532499
# Processing Salalah with id 286621
# Processing Uyuni with id 3901903
# Processing Hermanus with id 3366880
# Processing Bluff with id 2175403
# Processing Ushuaia with id 3833367
# Processing Bonavista with id 5905393
# Processing Straumen with id 3135728
# Processing Cherkasskoye with id 569170
# Processing Oxford with id 4081914
# Processing Nadym with id 1498087
# Processing Bismarck with id 5688025
# Processing Qaanaaq with id 3831208
# qurbah not found
# Processing Hobart with id 2163355
# Processing Avarua with id 4035715
# Processing Saskylakh with id 2017155
# Processing Kapaa with id 5848280
# sakakah not found
# Processing Salamanca with id 3111108
# mys shmidta not found
# Processing Saint-Philippe with id 6138908
# Processing Busselton with id 2075265
# Processing Hami with id 1529484
# Processing Acapulco with id 3533462
# Processing Lethem with id 3379316
# Processing Sao Domingos with id 3449293
# Processing Cape Town with id 3369157
# Processing Tchaourou with id 2391377
# belushya guba not found
# Processing Puerto Ayora with id 3652764
# Processing Port Alfred with id 964432
# Processing Vertientes with id 3534363
# Processing Rikitea with id 4030556
# Processing Jamestown with id 2069194
# Processing Ilulissat with id 3423146
# Processing Kahului with id 5847411
# Processing Evensk with id 2125693
# Processing Tuktoyaktuk with id 6170031
# Processing Punta Arenas with id 3874787
# taburi not found
# barentsburg not found
# attawapiskat not found
# Processing Bonthe with id 2409914
# Processing Kaeo with id 2189343
# Processing Longido with id 155848
# Processing Bredasdorp with id 1015776
# Processing Nanortalik with id 3421765
# Processing Clyde River with id 5924351
# Processing Butaritari with id 2110227
# sulina not found
# Processing Sao Bento do Sul with id 3449350
# Processing Sept-Iles with id 6144312
# Processing Paramonga with id 3933024
# Processing Svetlogorsk with id 584051
# mendahara not found
# Processing Tianjin with id 1792947
# Processing Madison with id 5261457
# Processing Albany with id 5106834
# Processing Norman Wells with id 6089245
# buqayq not found
# Processing Alexandria with id 4314550
# yambio not found
# Processing Yellowknife with id 6185377
# Processing Mataura with id 6201424
# Processing Sechura with id 3691954
# Processing Vila Velha with id 6320062
# Processing Ngunguru with id 2186111
# Processing Arlit with id 2447513
# Processing San Quintin with id 1688687
# Processing Mar del Plata with id 3863379
# illoqqortoormiut not found
# Processing Barrow with id 3833859
# Processing Isangel with id 2136825
# Processing Bilibino with id 2126682
# Processing Vaini with id 1273574
# Processing Ribeira Grande with id 3372707
# Processing Faanui with id 4034551
# Processing Ponta do Sol with id 3453439
# Processing Tuy Hoa with id 1563281
# Processing Khatanga with id 2022572
# Processing Jiaocheng with id 1806041
# Processing Albury with id 2178174
# Processing Port Elizabeth with id 4501427
# Processing Litovko with id 2020738
# Processing Nikolskoye with id 546105
# Processing Georgetown with id 3378644
# Processing Castro with id 3896218
# Processing Rio Grande with id 3451138
# Processing Kodiak with id 4407665
# Processing Hilo with id 5855927
# Processing Inzhavino with id 556275
# Processing High Level with id 5975004
# Processing Lerwick with id 2644605
# Processing Arraial do Cabo with id 3471451
# Processing Esperance with id 3573739
# Processing Mahebourg with id 934322
# olafsvik not found
# Processing La Peca with id 3695675
# Processing Vytegra with id 469960
# Processing Atuona with id 4020109
# Processing Kavaratti with id 1267390
# Processing Te Anau with id 2181625
# Processing Araouane with id 2460954
# Processing Cartagena with id 2520058
# Processing Torbay with id 6167817
# Processing Vao with id 588365
# Processing Shakhunya with id 496012
# Processing Manono with id 209598
# Processing Talnakh with id 1490256
# Processing Tiksi with id 2015306
# Processing Thunder Bay with id 6166142
# Processing Constitucion with id 4011743
# Processing Coromandel with id 2192093
# Processing Harper with id 4696310
# Processing Nome with id 4732862
# Processing Almora with id 1278974
# Processing Mehnagar with id 1263189
# Processing Ancud with id 3899695
# Processing Alofi with id 4036284
# tidore not found
# Processing Dori with id 2361082
# Processing Egvekinot with id 4031742
# Processing Cayenne with id 3382160
# taolanaro not found
# Processing Klaksvik with id 2618795
# karaul not found
# Processing Ostrovnoy with id 556268
# Processing Verkhoyansk with id 2013465
# Processing Kargil with id 1267776
# Processing Lagoa with id 2267254
# Processing Belaya Gora with id 2126785
# Processing Poum with id 787487
# Processing Cherskiy with id 2126199
# Processing Geraldton with id 5960603
# tsihombe not found
# Processing Innisfail with id 5983430
# Processing Naze with id 2337542
# Processing Lancut with id 766810
# Processing San Cristobal with id 3652462
# Processing Souillac with id 3026644
# aflu not found
# Processing Sisimiut with id 3419842
# Processing Mount Gambier with id 2156643
# Processing Saint George with id 262462
# Processing Marsa Matruh with id 352733
# Processing Bathsheba with id 3374083
# Processing Thompson with id 6165406
# Processing Lebu with id 344979
# Processing Tazovskiy with id 1489853
# waw not found
# Processing Cidreira with id 3466165
# Processing Miri with id 2347470
# Processing Guerrero Negro with id 4021858
# Processing Chuy with id 3443061
# Processing New Norfolk with id 2155415
# Processing Moquegua with id 3934608
# Processing Aklavik with id 5882953
# Processing Bawku with id 2303287
# Processing Upernavik with id 3418910
# Processing Dingle with id 1714733
# Processing Port Hedland with id 2063042
# Processing Luderitz with id 3355672
# Processing Dunedin with id 2191562
# Processing Sambava with id 1056899
# Processing Hithadhoo with id 1282256
# Processing Sterling with id 4787534
# Processing Nchelenge with id 175499
# lolua not found
# Processing Touros with id 3386213
# Processing Vardo with id 4372777
# Processing Lorengau with id 2092164
# Processing Acajutla with id 3587498
# Processing Lichtenburg with id 982899
# Processing Kirakira with id 2178753
# Processing Chokurdakh with id 2126123
# Processing Tarumovka with id 484290
# Processing Margate with id 2158744
# svetlyy not found
# Processing Taltal with id 3870243
# Processing Ivanjica with id 789988
# Processing Viedma with id 3832899
# Processing Atherton with id 2656847
# Processing Kavieng with id 2094342
# Processing San-Pedro with id 2282006
# Processing Ugoofaaru with id 1337619
# Processing Taoudenni with id 2450173
# Processing San Patricio with id 3437029
# Processing Horodyshche with id 702116
# Processing Honiara with id 2108502
# Processing Sibiti with id 2255285
# grand river south east not found
# Processing Tiarei with id 4033356
# Processing Grootfontein with id 3357114
# Processing Victoria with id 1733782
# Processing Marfino with id 503977
# Processing Oranjemund with id 3354071
# Processing Piacabucu with id 3454005
# Processing Knysna with id 988698
# Processing Nouadhibou with id 2377457
# Processing Athabasca with id 5887916
# Processing Faya with id 110690
# Processing Trincomalee with id 1226260
# Processing Pangkalanbuun with id 1632694
# samusu not found
# Processing Plouzane with id 2986626
# labutta not found
# Processing Kaitangata with id 2208248
# Processing Sulangan with id 1685422
# Processing Kailua with id 5847486
# Processing Jacareacanga with id 3397763
# Processing Howard Springs with id 6301965
# Processing Mackay with id 5921525
# Processing Calama with id 3897347
# kusye-aleksandrovskiy not found
# Processing Jimma with id 333772
# Processing Puerto Madryn with id 3840092
# Processing Sola with id 643453
# Processing Sibu with id 1735902
# Processing La Plata with id 3432043
# Processing Pevek with id 2122090
# Processing Erzin with id 296852
# tutla not found
# Processing Yenagoa with id 2318123
# Processing West Wendover with id 5710035
# Processing Fortuna with id 2517679
# Processing Meulaboh with id 1214488
# Processing Goderich with id 5962442
# Processing Rome with id 6539761
# Processing Sao Joao da Barra with id 3448903
# qui nhon not found
# Processing Pochutla with id 3517970
# Processing Sistranda with id 3139597
# Processing Nehe with id 2035610
# Processing Port Macquarie with id 2152659
# louisbourg not found
# Processing Ejutla de Crespo with id 3529510
# tumannyy not found
# Processing Camacha with id 2270385
# Processing Huarmey with id 3939168
# Processing Atar with id 2381334
# Processing Arman with id 2127060
# Processing Duldurga with id 2024812
# Processing Nuuk with id 3421319
# Processing Sanbu with id 1797873
# Processing Santa Rosa with id 3835994
# Processing Beloha with id 1067565
# Processing San Miguel with id 3430545
# Processing Vila do Maio with id 3374120
# turtkul not found
# Processing Along with id 1278969
# Processing Dubovskoye with id 564593
# Processing Carnarvon with id 1014034
# Processing Galle with id 4695361
# rawannawi not found
# Processing Baijiantan with id 1529626
# Processing Solnechnyy with id 2016307
# asau not found
# Processing Inuvik with id 5983607
# Processing Port-Gentil with id 2396518
# Processing Nsoko with id 934900
# Processing Longyearbyen with id 2729907
# Processing Havoysund with id 779622
# Processing Hobyo with id 57000
# Processing Jalu with id 86049
# Processing Soyo with id 2236967
# Processing Ola with id 2122574
# Processing Petropavlovsk-Kamchatskiy with id 2122104
# Processing Angoram with id 2100765
# Processing Hofn with id 2630299
# Processing Aksha with id 2028028
# yershov not found
# Processing Celestun with id 3531368
# Processing Plettenberg Bay with id 964712
# Processing Hillsborough with id 5357155
# Processing Vilnius with id 593116
# Processing Magadan with id 2123628
# Processing Kamaishi with id 2112444
# saleaula not found
# Processing Nelson Bay with id 2155562
# Processing Kirovsk with id 548391
# Processing Severo-Kurilsk with id 2121385
# Processing Yar-Sale with id 1486321
# Processing Bambanglipuro with id 1650434
# Processing Dabhol with id 1273765
# camana not found
# Processing Vila with id 3164565
# Processing Northam with id 2641434
# Processing Esik with id 1523741
# Processing Provideniya with id 4031574
# Processing Los Llanos de Aridane with id 2514651
# Processing Mitsamiouli with id 921786
# Processing Gonnoi with id 261996
# Processing Bela Vista with id 3470177
# cape elizabeth not found
# Processing Kaitong with id 2036338
# Processing Port Moresby with id 2088122
# Processing Pacifica with id 5380420
# Processing Belyy Yar with id 1510377
# Processing Ubeda with id 3116507
# Processing Ulladulla with id 2145554
# Processing Sao Filipe with id 3374210
# Processing Inta with id 1505579
# Processing Gubkinskiy with id 1539209
# Processing Pimenta Bueno with id 3924908
# Processing Virginia Beach with id 4791259
# Processing Paita with id 3694112
# Processing Broken Hill with id 2173911
# Processing Tilichiki with id 2120591
# Processing Roquetas de Mar with id 2511716
# Processing Zhangzhou with id 1785018
# andenes not found
# Processing Puerto Palomas with id 3991350
# Processing La Romana with id 3500957
# Processing Ahipara with id 2194098
# Processing Dudinka with id 1507116
# Processing Puri with id 1635111
# Processing Ayagoz with id 1525988
# Processing Adrar with id 2508813
# Processing Chiang Rai with id 1153669
# abomsa not found
# Processing Namibe with id 3347019
# Processing Aljezur with id 2271968
# galiwinku not found
# Processing Iqaluit with id 5983720
# Processing Majene with id 1636806
# buariki not found
# Processing Scottsbluff with id 5699404
# Processing Myanaung with id 1308204
# Processing Tacuarembo with id 3440034
# Processing Kruisfontein with id 986717
# Processing Neka with id 122397
# Processing Letlhakane with id 933535
# Processing Nsukka with id 2328684
# Processing Cabedelo with id 3404558
# Processing Lasa with id 146639
# Processing Santiago with id 3871336
# Processing Castilho with id 3466708
# Processing Cabo San Lucas with id 3985710
# port-de-paix not found
# bairiki not found
# Processing Shenkursk with id 494884
# Processing Caramay with id 1718517
# Processing Kuito with id 3348078
# Processing Mishkino with id 543018
# Processing Victoriaville with id 6174151
# barbar not found
# chagda not found
# Processing Vestmannaeyjar with id 3412093
# amderma not found
# Processing Fort Nelson with id 5955902
# Processing Umm Kaddadah with id 364933
# Processing Oussouye with id 2246901
# Processing Zarand with id 111421
# Processing Slave Lake with id 6149374
# Processing Uray with id 1488429
# Processing Lokosovo with id 1500399
# Processing Lakes Entrance with id 2160735
# Processing Katsuura with id 1865309
# Processing Chum Phae with id 1611026
# Processing Port-Cartier with id 6111696
# Processing Deputatskiy with id 2028164
# palabuhanratu not found
# ondorhaan not found
# Processing Ewa Beach with id 5855051
# Processing Rawson with id 3839307
# mahadday weyne not found
# Processing Zhigalovo with id 2012532
# Processing Komsomolskiy with id 1486910
# Processing Nyurba with id 2018735
# Processing Avera with id 4231997
# Processing Namatanai with id 2090021
# Processing Hanna with id 5970234
# Processing Alice Springs with id 2077895
# Processing Lompoc with id 5367788
# Processing Letpadan with id 1292313
# Processing Huntsville with id 4068590
# Processing Dannenberg with id 2938991
# Processing Tsaratanana with id 1055059
# vaitupu not found
# urumqi not found
# Processing Bogo with id 2233805
# Processing Port Blair with id 1259385
# Processing Chandbali with id 1274761
# Processing College with id 5859699
# Processing Kayes with id 2455518
# Processing Skelleftea with id 602913
# Processing Campos Altos with id 3467688
# Processing San Fernando with id 3573739
# Processing Irondale with id 4406884
# Processing Chuhar Kana with id 1180983
# longlac not found
# Processing Portland with id 5746545
# Processing Ust-Kuyga with id 2013921
# Processing Rabo de Peixe with id 3372745
# Processing Guanare with id 3640226
# Processing Boda with id 1185141
# Processing Kutum with id 371745
# Processing Smithers with id 6149996
# Processing Trollhattan with id 2667303
# Processing Katobu with id 1640972
# Processing Kununurra with id 2068110
# Processing Gilbues with id 3398931
# Processing Imbituba with id 3461370
# Processing Whitehorse with id 6180550
# Processing Dubai with id 292223
# Processing Urbano Santos with id 3385726
# Processing Monywa with id 1308522
# Processing Bandarbeyla with id 64814
# Processing Sao Gabriel da Cachoeira with id 3662342
# Processing Meadow Lake with id 6071421
# meyungs not found
# Processing Bhandaria with id 1477498
# Processing Hasaki with id 2112802
# Processing Sobolevo with id 525426
# Processing Grand Gaube with id 934479
# Processing Daru with id 2409663
# Processing Zhengjiatun with id 2033135
# Processing Jurm with id 1139085
# Processing Motygino with id 1498314
# Processing Oum Hadjer with id 2426370
# Processing Waingapu with id 1622318
# khonuu not found
# Processing Matara with id 3948642
# Processing Bucak with id 320533
# Processing Troitskoye with id 1489209
# Processing Tezu with id 1254709
# Processing Sitka with id 4267710
# nizhneyansk not found
# Processing Kasane with id 933677
# Processing Gizo with id 6693679
# Processing Swift Current with id 6160603
# Processing Paamiut with id 3421193
# Processing Saint-Francois with id 2980080
# Processing Rodrigues Alves with id 3665210
# Processing Yulara with id 6355222
# Processing Pontianak with id 1630789
# Processing Tiznit with id 2527089
# Processing Yerofey Pavlovich with id 2012938
# Processing Abalak with id 2448245
# Processing Lugovoy with id 1498919
# burica not found
# Processing Caravelas with id 3466980
# Processing Tasiilaq with id 3424607
# Processing Ubinskoye with id 1488708
# Processing Chhatak with id 1185254
# Processing Tarakan with id 1624725
# Processing Khash with id 1160571
# Processing Visnes with id 3131500
# Processing Balkanabat with id 161616
# Processing Adeje with id 2319133
# Processing Codajas with id 3664525
# Processing Lanivtsi with id 703397
# Processing Bukachacha with id 2026023
# Processing Maragogi with id 3395458
# Processing Molokovo with id 525509
# Processing Henties Bay with id 3356832
# Processing Mount Isa with id 2065594
# Processing Kuytun with id 2021093
# Processing Yadrin with id 469809
# Processing Hirara with id 1862505
# Processing Glendive with id 5654391
# Processing Joao Pinheiro with id 3459785
# Processing Santa Maria with id 3450083
# katsiveli not found
# puunsi not found
# Processing Vila Franca do Campo with id 3372472
# marcona not found
# Processing Dekernes with id 358172
# Processing Krasnyy Chikoy with id 2012349
# Processing Kawalu with id 1640902
# Processing Boyolangu with id 1648082
# Processing Zonguldak with id 737021
# Processing Coihaique with id 3894426
# Processing Bah with id 1277841
# Processing Statesville with id 4493316
# Processing Half Moon Bay with id 5354943
# Processing Banda Aceh with id 1215502
# Processing Itarema with id 3393692
# Processing Coquimbo with id 3893629
# Processing Blackwater with id 2639577
# Processing Ixtapa with id 4004293
# Processing Ganta with id 2277197
# Processing Neiafu with id 4032420
# Processing Mayo with id 6068416
# Processing Brownwood with id 4676798
# Processing Honningsvag with id 779554
# ojitlan not found
# kemijarvi not found
# Processing Koubia with id 2418764
# Processing Kilindoni with id 157429
# Processing Salinopolis with id 3389822
# Processing Udachnyy with id 2014624
# Processing Mayumba with id 2399001
# shcholkine not found
# Processing Kieta with id 2094027
# Processing Comodoro Rivadavia with id 3860443
# Processing Troyes with id 2971549
# Processing Wabrzezno with id 3082734
# Processing Saltillo with id 3988086
# Processing Aksu with id 1524298
# Processing Lagos with id 2332459
# Processing Joutseno with id 655563
# Processing Sovetskiy with id 490040
# Processing Sorland with id 3137469
# Processing Rumonge with id 423549
# Processing Port Hardy with id 6111862
# Processing Kaka with id 161901
# Processing Carutapera with id 3402648
# Processing Barcelos with id 2742416
# Processing Yermakovskoye with id 1485904
# Processing Alirajpur with id 1258815
# turkistan not found
# Processing Yuanping with id 1786060
# pipar not found
# Processing Lavrentiya with id 4031637
# Processing Dayong with id 1712986
# Processing Shitanjing with id 1794971
# haibowan not found
# Processing Baoqing with id 2038446
# Processing Ambilobe with id 1082243
# Processing Castro-Urdiales with id 3125621
# Processing Sao Luis de Montes Belos with id 3448558
# Processing Samarai with id 2132606
# Processing Saldanha with id 2737599
# Processing Venice with id 4176380
# Processing Arkhara with id 2027487
# Processing Moranbah with id 6533368
# Processing Santa Isabel do Rio Negro with id 3662489
# Processing Gamba with id 1281256
# Processing Waipawa with id 2185329
# Processing Batemans Bay with id 2176639
# Processing Atasu with id 1526041
# Processing Butterworth with id 1735076
# yanan not found
# Processing Lata with id 1253628
# Processing Shenzhen with id 1795565
# Processing Dwarka with id 1273294
# Processing Mamlyutka with id 1521153
# Processing Buala with id 2109528
# Processing Pirovskoye with id 1494941
# Processing Mahibadhoo with id 1337605
# Processing Elat with id 2232283
# Processing Amapa with id 3603330
# Processing Goure with id 2444219
# Processing Utete with id 149070
# Processing Methoni with id 257122
# satitoa not found
# Processing Zastron with id 937246
# Processing Taonan with id 2034497
# Processing Booue with id 2401495
# Processing Beecher with id 4884352
# Processing Airai with id 1651810
# Processing Ravar with id 118704
# Processing Acari with id 3390864
# Processing Orsha with id 624079
# pietersburg not found
# Processing Karratha with id 6620339
# Processing Parana with id 3663516
# Processing Okhotsk with id 2122605
# Processing Vaitape with id 4033077
# Processing Sao Jose dos Campos with id 3448636
# Processing Suluq with id 81604
# Processing Tikrit with id 90150
# Processing Gerash with id 133595
# Processing Kirovskiy with id 2022064
# Processing Cockburn Town with id 3576994
# Processing Xinmin with id 2033675
# Processing Fuyang with id 1810845
# Processing Prescott with id 5309842
# Processing La Asuncion with id 3652350
# Processing Inhambane with id 1045114
# sahrak not found
# Processing Pabrade with id 596473
# Processing Shingu with id 1847947
# Processing Belmonte with id 8010472
# Processing Beringovskiy with id 2126710
# Processing Seydi with id 2448024
# Processing East London with id 1006984
# Processing Quatre Cocos with id 1106643
# jiroft not found
# Processing Ponta Delgada with id 3372783
# Processing Kushiro with id 2129072
# Processing Kenai with id 5866063
# Processing Fairbanks with id 5861897
# Processing Manaure with id 3675504
# Processing Omsukchan with id 2122493
# Processing Mahon with id 2965139
# Processing Benito Juarez with id 3991622
# Processing Port Loko with id 2404433
# Processing Maningrida with id 2067089
# Processing Robertsport with id 2274275
# Processing Pisco with id 3932145
# Processing Sur with id 286245
# Processing Price with id 5545269
# Processing Victor Harbor with id 2059470
# ruatoria not found
# Processing Islamkot with id 1176608
# Processing Bubaque with id 2374583
# Processing Vung Tau with id 1562414
# Processing Maceio with id 3395981
# Processing Mehamn with id 778707
# yomitan not found
# name          539
# id            539
# lat           539
# windspeed     539
# temp          539
# humidity      539
# cloudiness    539
# dtype: int64

# %%
summary_df.head()
# Out:
#             name       id    lat  windspeed   temp  humidity  cloudiness
# 0     North Bend  5742974  43.41       2.60  11.70        83           1
# 1  Puerto Suarez  3465342 -18.96       2.32  33.00        59           0
# 2     Port Keats  2063039 -14.25       0.12  23.05        83          20
# 3         Dikson  1507390  73.51       6.97   4.80        92          92
# 4         Bethel  5880568  60.79       1.27   5.60       100          90

# %%
#for all scatter plots
def weather_scat (index,column,y_label,fig_title,outfile_name):
    """
    index determines color graph
    column - str for the column in summary_df to use for y values
    y_label - the y axis label (x_axis is latitude values)
    fig-title - the graph title
    outfile_name -  .png file for saving the graph 
    """
    
    colors=("red","blue","grey","green")
    fig,ax=plt.subplots(figsize=(7,7),facecolor="lightgrey")
    ax.set_facecolor('white')
 #set x axis   
    x_axis=summary_df["lat"]
    ax.set_xlabel("Latitude",fontsize=12)
 #set y axis   
    y_data=summary_df[column]
    ax.set_ylabel(y_label,fontsize=12)
#plot and save to file    
    ax.grid()
    fig.suptitle(fig_title, fontsize=16)
    ax.scatter(x_axis,y_data,marker='o',facecolor=colors[index],edgecolor="black")
    plt.savefig(outfile_name)
    plt.show()
    return

# %%
#Temp vs Lat scatterplot
weather_scat(0,"temp","Temperature (celsius)","City Latitude vs. Temperature  "+today,temp_file)

# %%
#humidity vs latitude scatterplot
weather_scat(1,"humidity","Humidity(%)","City Latitude vs. Humidity "+today,humidity_file)

# %%
#cloudiness vs latitude
weather_scat(2,"cloudiness","Cloudiness (%)","City Latitude vs.Cloudiness "+today,cloud_file)

# %%
#wind speed vs latitude
weather_scat(3,"windspeed","Wind Speed (m/sec)","City Latitude vs.Wind Speed "+today,wind_file)
