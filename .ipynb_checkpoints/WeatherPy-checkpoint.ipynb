# %%
#%matplotlib notebook
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from datetime import date
import time
import openweathermapy.core as owm
# Import API key
from api_keys import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"
#Output files (PNG)
temp_file="output_data/temp_graph.png"
humidity_file="output_data/humidity_graph.png"
cloud_file="output_data/cloud_graph.png"
wind_file="output_data/wind_graph.png"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)
#date for labeling graphs
today=str(date.today())

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 587

# %% [markdown]
# ## Perform API Calls

# %%
# OpenWeatherMap url = "http://api.openweathermap.org/data/2.5/weather?"
# Create settings dictionary with information we're interested in
settings = {"units": "metric", "appid": api_key}
summary=["name","id","coord.lat","wind.speed","main.temp","main.humidity","clouds.all"]

# %%
summary_data=[]
for city in cities:
    try:
        current_weather=owm.get_current(city, **settings)
        city_data=current_weather(*summary)
        summary_data.append(city_data)
        print(f"Processing {current_weather['name']} with id {current_weather['id']} ")        
    except:
        print(f"{city} not found")

#convert to dataframe and name columns        
summary_df=pd.DataFrame(summary_data)
summary_df=summary_df.rename(columns={0:"name",1:"id",2:"lat",3:"windspeed",4:"temp",5:"humidity",6:"cloudiness"})
#save to file
summary_df.to_csv(output_data_file,index=False,header=True)
#confirm sufficient count after cities found
summary_df.count()
# Out:
# Processing Mataura with id 6201424
# Processing Buala with id 2109528
# Processing Punta Arenas with id 3874787
# Processing Ixtapa with id 4004293
# Processing Busselton with id 2075265
# Processing Yulara with id 6355222
# Processing Trofors with id 3133983
# Processing Khromtau with id 609404
# Processing Jalu with id 86049
# Processing Tiksi with id 2015306
# Processing Davila with id 1715335
# Processing Port Alfred with id 964432
# Processing Myaundzha with id 2123100
# Processing Bluff with id 2175403
# attawapiskat not found
# Processing Cabo San Lucas with id 3985710
# Processing Sergeyevka with id 1519385
# Processing Vuktyl with id 470905
# Processing Thompson with id 6165406
# Processing Faanui with id 4034551
# gulshat not found
# belushya guba not found
# Processing Albany with id 5106834
# Processing Morondava with id 1058381
# Processing Hermanus with id 3366880
# Processing Pisco with id 3932145
# Processing Dikson with id 1507390
# Processing Porto Novo with id 6322184
# Processing Grindavik with id 3416888
# Processing Nikolskoye with id 546105
# Processing Vaini with id 1273574
# Processing Pevek with id 2122090
# Processing Atuona with id 4020109
# Processing Zonguldak with id 737021
# Processing Ushuaia with id 3833367
# Processing Saint George with id 262462
# Processing Kodiak with id 4407665
# Processing Broadford with id 2962283
# Processing Bosaso with id 64013
# Processing Nantucket with id 4944903
# Processing Waingapu with id 1622318
# Processing Kahului with id 5847411
# Processing Road Town with id 3577430
# Processing Lebu with id 344979
# Processing Broken Hill with id 2173911
# Processing Rikitea with id 4030556
# Processing Malm with id 3146508
# Processing Saldanha with id 2737599
# Processing Mumford with id 2297810
# Processing Avarua with id 4035715
# Processing Castro with id 3896218
# taolanaro not found
# Processing Mecca with id 104515
# Processing Hilo with id 5855927
# Processing Svetlaya with id 2015852
# Processing Santa Rosa with id 3835994
# Processing Raudeberg with id 3146487
# Processing Hasaki with id 2112802
# Processing Kavieng with id 2094342
# Processing Bolong with id 1969335
# Processing Hobart with id 2163355
# Processing Jamestown with id 2069194
# Processing Trairi with id 3386177
# Processing Kapaa with id 5848280
# Processing Zarand with id 111421
# Processing Saint-Philippe with id 6138908
# Processing Bredasdorp with id 1015776
# Processing Egvekinot with id 4031742
# umzimvubu not found
# Processing Mar del Plata with id 3863379
# marcona not found
# Processing Beloha with id 1067565
# Processing Ponta do Sol with id 3453439
# Processing Sisimiut with id 3419842
# Processing Mildura with id 2157698
# Processing Cape Town with id 3369157
# Processing Havelock with id 4470244
# Processing Abu Dhabi with id 292968
# Processing Srednekolymsk with id 2121025
# rungata not found
# Processing Bayir with id 304183
# Processing Luderitz with id 3355672
# Processing Solnechnyy with id 2016307
# Processing Hofn with id 2630299
# Processing Issoudun with id 3012655
# Processing Kuytun with id 2021093
# Processing Port Elizabeth with id 4501427
# Processing Laguna with id 4013704
# Processing Knin with id 3197986
# Processing Cherskiy with id 2126199
# Processing Porto Nacional with id 3452711
# Processing Puerto Palomas with id 3991350
# Processing Augustow with id 776597
# Processing Upernavik with id 3418910
# Processing Coxim with id 3465228
# Processing Flin Flon with id 5954718
# Processing Esperance with id 3573739
# Processing Gondanglegi with id 1640660
# Processing Narsaq with id 3421719
# Processing Longyearbyen with id 2729907
# Processing Butaritari with id 2110227
# Processing Saskylakh with id 2017155
# tsihombe not found
# Processing Zaysan with id 1517060
# Processing Katherine with id 2068655
# Processing Padang with id 1633419
# Processing Xinzhi with id 1670479
# Processing Cockburn Town with id 3576994
# Processing Orje with id 3143427
# Processing Inverbervie with id 2646134
# Processing Aklavik with id 5882953
# Processing Ambulu with id 1621313
# Processing Victoria with id 1733782
# Processing Terrace with id 6162949
# Processing Griffith with id 2164422
# Processing Auki with id 2339937
# Processing Kharan with id 1174062
# Processing Yellowknife with id 6185377
# Processing Bethel with id 5880568
# Processing Maningrida with id 2067089
# Processing Fandriana with id 1065222
# Processing Mount Gambier with id 2156643
# Processing Karachi with id 1174872
# Processing Ambikapur with id 1278827
# Processing Saint-Francois with id 2980080
# Processing Stavern with id 3137091
# illoqqortoormiut not found
# Processing Nanortalik with id 3421765
# Processing Kedgwick with id 6942800
# Processing Tuktoyaktuk with id 6170031
# Processing Puerto Ayora with id 3652764
# Processing Praia da Vitoria with id 3372760
# Processing La Union with id 3593500
# Processing New Norfolk with id 2155415
# Processing Samarai with id 2132606
# Processing Pacific Grove with id 5380437
# Processing Menongue with id 3347353
# Processing San Patricio with id 3437029
# barentsburg not found
# Processing Mehamn with id 778707
# Processing Fereydun Kenar with id 134602
# ngukurr not found
# nizhneyansk not found
# Processing Wana with id 1162634
# Processing Ribeira Grande with id 3372707
# Processing Khatanga with id 2022572
# Processing Iqaluit with id 5983720
# asfi not found
# Processing Mbaiki with id 2384770
# vaitupu not found
# Processing Airai with id 1651810
# Processing Gonbad-e Qabus with id 132938
# Processing Esil with id 1524296
# Processing Hithadhoo with id 1282256
# Processing Great Yarmouth with id 2647984
# Processing Lavrentiya with id 4031637
# Processing Beringovskiy with id 2126710
# Processing Fort-de-France with id 3570675
# Processing Kimovsk with id 548658
# Processing Chokurdakh with id 2126123
# Processing Fortuna with id 2517679
# Processing Talnakh with id 1490256
# hihifo not found
# paradwip not found
# Processing Zabaykalsk with id 2012780
# sentyabrskiy not found
# Processing Zyryanka with id 2119283
# Processing Leningradskiy with id 2123814
# palabuhanratu not found
# Processing Kobyzhcha with id 705524
# binabalian not found
# Processing Grand-Santi with id 3381538
# Processing Bilma with id 2446796
# Processing Hamilton with id 3573197
# Processing Mahebourg with id 934322
# Processing Grover Beach with id 5354552
# Processing Kununurra with id 2068110
# Processing Nur with id 763513
# Processing Lata with id 1253628
# Processing Fukue with id 1848373
# Processing Carutapera with id 3402648
# Processing Komsomolskiy with id 1486910
# Processing Sol-Iletsk with id 491019
# Processing Broome with id 2656067
# bolungarvik not found
# Processing Mao with id 3496831
# Processing Setubal with id 3836277
# Processing Acajutla with id 3587498
# Processing Gulabpura with id 1270763
# Processing Alta Floresta with id 6316343
# Processing Lae with id 2092740
# Processing Ajdabiya with id 89113
# Processing Paamiut with id 3421193
# Processing Qaanaaq with id 3831208
# Processing Boguchany with id 1509844
# Processing Brae with id 2654970
# Processing Barrow with id 3833859
# Processing Bandarbeyla with id 64814
# Processing Arraial do Cabo with id 3471451
# Processing Bogovina with id 792502
# Processing Deputatskiy with id 2028164
# Processing Georgetown with id 3378644
# Processing Vestmanna with id 2610343
# Processing Arica with id 3899361
# Processing Sao Filipe with id 3374210
# Processing Half Moon Bay with id 5354943
# mahadday weyne not found
# kousseri not found
# Processing Tura with id 1254046
# Processing Ancud with id 3899695
# Processing Pischia with id 670659
# Processing Klyuchi with id 1503153
# Processing Namibe with id 3347019
# Processing Presidencia Roque Saenz Pena with id 3840300
# Processing Namatanai with id 2090021
# Processing Porbandar with id 1259395
# Processing San Luis with id 3837056
# Processing Prince Rupert with id 6113406
# Processing Trinidad with id 3439749
# Processing Santiago with id 3871336
# Processing Orobo with id 2328684
# Processing Naze with id 2337542
# Processing Vardo with id 4372777
# bengkulu not found
# Processing Impfondo with id 2259655
# Processing Dingle with id 1714733
# Processing Bandarban with id 1185270
# Processing Ostrovnoy with id 556268
# Processing Kamaishi with id 2112444
# Processing Tezu with id 1254709
# Processing Kodino with id 546742
# Processing Tasiilaq with id 3424607
# Processing Tarko-Sale with id 1490085
# Processing Rojhan with id 1166819
# Processing Kropotkin with id 540761
# Processing Effium with id 2343985
# Processing Vila Franca do Campo with id 3372472
# Processing Kilifi with id 192067
# Processing Taltal with id 3870243
# Processing Severo-Kurilsk with id 2121385
# Processing Verkhnevilyuysk with id 2013639
# Processing Santa Isabel do Rio Negro with id 3662489
# Processing Nouadhibou with id 2377457
# Processing Nyurba with id 2018735
# Processing Katsuura with id 1865309
# Processing Pangkalanbuun with id 1632694
# Processing Astaneh-ye Ashrafiyeh with id 142679
# Processing Cowra with id 2170139
# Processing Abha with id 110690
# Processing Bowen with id 2174444
# Processing Kisangani with id 212730
# yambio not found
# Processing Troitskoye with id 1489209
# Processing Saint-Georges with id 6295855
# Processing Zhigansk with id 2012530
# Processing Berlevag with id 780687
# Processing Jaca with id 3120211
# Processing Razumnoye with id 502400
# Processing Staroaleyskoye with id 1491006
# Processing Flinders with id 6255012
# Processing Tuatapere with id 2180815
# Processing Novopokrovka with id 2018888
# mys shmidta not found
# Processing Ahuimanu with id 5856516
# Processing Delijan with id 136399
# Processing San Cristobal with id 3652462
# Processing Caravelas with id 3466980
# Processing Cururupu with id 3401148
# Processing Dakar with id 2253354
# Processing Hudson Bay with id 5978133
# Processing Mayumba with id 2399001
# Processing Imbituba with id 3461370
# Processing Sechura with id 3691954
# Processing Ishigaki with id 1861416
# amderma not found
# Processing Geraldton with id 5960603
# Processing Big Rapids with id 4986020
# Processing East London with id 1006984
# Processing Malindi with id 187968
# Processing Fairbanks with id 5861897
# Processing Bubaque with id 2374583
# grand river south east not found
# Processing Ballina with id 2966778
# Processing Chuy with id 3443061
# Processing Almaznyy with id 582447
# Processing Te Anau with id 2181625
# Processing Sabratah with id 2212771
# Processing Yumen with id 1528998
# Processing Makasar with id 1642911
# Processing Golkoy with id 746628
# Processing Yagodnoye with id 2119626
# Processing Turukhansk with id 1488903
# Processing Fort Nelson with id 5955902
# Processing Comodoro Rivadavia with id 3860443
# Processing Bambous Virieux with id 1106677
# Processing Swakopmund with id 3352844
# Processing Kirksville with id 5055787
# Processing Soyo with id 2236967
# Processing La Ligua with id 3885456
# Processing Touros with id 3386213
# Processing Vila Velha with id 6320062
# Processing Constitucion with id 4011743
# Processing Hami with id 1529484
# Processing Novyy Urengoy with id 1496511
# Processing Rengo with id 3873441
# Processing Norman Wells with id 6089245
# Processing Aripuana with id 3665202
# Processing Marsh Harbour with id 3571913
# Processing Semnan with id 116402
# Processing Brighton with id 2654710
# Processing Nome with id 4732862
# Processing Noumea with id 2139521
# Processing Lasa with id 146639
# Processing Zhicheng with id 1805012
# Processing Mogadishu with id 53654
# Processing Seka with id 333772
# Processing Baruun-Urt with id 2032614
# Processing Umm Kaddadah with id 364933
# Processing Bend with id 5713587
# Processing Sitka with id 4267710
# Processing Brigantine with id 4500920
# Processing Kjollefjord with id 779261
# samusu not found
# Processing Kutum with id 371745
# Processing Tudela with id 3107418
# Processing Lakes Entrance with id 2160735
# Processing Yabelo with id 326036
# Processing Waipawa with id 2185329
# Processing Salvador with id 3450554
# Processing Nueva Concepcion with id 3592145
# Processing Sinjar with id 174611
# Processing Bulgan with id 2032201
# nguiu not found
# Processing Navirai with id 3456368
# Processing Vanimo with id 2084442
# Processing Bonavista with id 5905393
# Processing Sarangani with id 1687186
# Processing Ojojona with id 3604270
# Processing Cap Malheureux with id 934649
# Processing Maceio with id 3395981
# Processing Yarmouth with id 2633414
# Processing Lompoc with id 5367788
# Processing Snasa with id 3138076
# Processing Banda Aceh with id 1215502
# Processing Paita with id 3694112
# Processing Labuhan with id 1641899
# Processing Provideniya with id 4031574
# Processing Itoman with id 1861280
# Processing Netrakona with id 1185116
# Processing Kloulklubed with id 7671223
# Processing Torbay with id 6167817
# Processing Hulan Ergi with id 2036670
# Processing Mocuba with id 1024312
# Processing Salym with id 1493162
# Processing Uruacu with id 3445713
# Processing Saint-Augustin with id 3031582
# Processing Poum with id 787487
# Processing Mitsamiouli with id 921786
# Processing Ranong with id 1150965
# Processing Pangody with id 1495626
# Processing Shitanjing with id 1794971
# Processing Verkhnyaya Inta with id 1487332
# Processing Inhambane with id 1045114
# Processing Navan with id 2962308
# Processing Bumba with id 217745
# Processing Lac du Bonnet with id 6014443
# Processing Lamar with id 5427957
# Processing Lodja with id 211647
# Processing Cabra with id 2520645
# Processing Tiarei with id 4033356
# Processing Zlobin with id 3191648
# Processing Letnyaya Stavka with id 535605
# Processing Victor Harbor with id 2059470
# Processing Bad Frankenhausen with id 2953459
# Processing Carnarvon with id 1014034
# Processing Sawakin with id 367544
# Processing Oriximina with id 3393471
# saleaula not found
# Processing Mudgee with id 2156404
# Processing Mahanoro with id 1062553
# Processing Codrington with id 2160063
# Processing Yatou with id 2225940
# Processing Verkhoyansk with id 2013465
# Processing Strezhevoy with id 1490796
# Processing San Vicente with id 3583178
# Processing Virginia Beach with id 4791259
# Processing Sao Joao da Barra with id 3448903
# Processing Copiapo with id 3893656
# Processing Port Hardy with id 6111862
# Processing Seymchan with id 2121373
# Processing Pimenta Bueno with id 3924908
# Processing Gorom-Gorom with id 2360372
# Processing Husavik with id 5961417
# Processing Bathsheba with id 3374083
# Processing Westport with id 2960970
# Processing Bontang with id 1648186
# Processing Sydney with id 2147714
# yefimovskiy not found
# Processing Teknaf with id 1185095
# Processing Kholmy with id 706335
# Processing Lekoni with id 2399831
# Processing Yantzaza with id 3650053
# Processing Himensulan with id 1711697
# Processing Romilly-sur-Seine with id 2982972
# Processing Monroe with id 5002344
# Processing Hambantota with id 1244926
# Processing Les Cayes with id 3728097
# Processing Saint Paul with id 5045360
# Processing Conde with id 3465713
# Processing Awjilah with id 88533
# Processing Lingao with id 1803560
# Processing Olenegorsk with id 515698
# asau not found
# Processing Port Lincoln with id 2063036
# Processing Knysna with id 988698
# Processing Bermeo with id 3128174
# Processing Erseke with id 783259
# Processing Hobyo with id 57000
# Processing Ciudad Bolivar with id 3645532
# Processing Knokke-Heist with id 2794216
# Processing Ucluelet with id 6171633
# Processing Tooele with id 5783695
# Processing Boyolangu with id 1648082
# Processing Bani with id 1695357
# Processing Coquimbo with id 3893629
# Processing Buraydah with id 107304
# tumannyy not found
# Processing Sassandra with id 2281951
# Processing Iracoubo with id 3381428
# Processing Lagoa with id 2267254
# Processing Sinnamary with id 3380290
# Processing Zeya with id 2012593
# Processing Swift Current with id 6160603
# Processing Margate with id 2158744
# Processing Tallahassee with id 4174715
# Processing San Juan with id 4568138
# Processing Strelka with id 1490805
# Processing Verkhnetulomskiy with id 475469
# Processing Sola with id 3137942
# Processing Lethem with id 3379316
# Processing Norrtalje with id 2688250
# Processing Cidreira with id 3466165
# Processing Bom Jesus with id 3405304
# Processing Chiang Khong with id 1611197
# Processing Sur with id 286245
# Processing Petropavlovsk-Kamchatskiy with id 2122104
# zhitikara not found
# Processing Evensk with id 2125693
# Processing Keti Bandar with id 1174451
# Processing Neuquen with id 3843123
# Processing Meulaboh with id 1214488
# pokanayevka not found
# Processing Codajas with id 3664525
# Processing Tulle with id 2971482
# ust-kamchatsk not found
# sofiysk not found
# Processing Partenit with id 709075
# Processing Isangel with id 2136825
# Processing Gravelbourg with id 5965462
# Processing Rorvik with id 3141310
# Processing Kamenka with id 553725
# Processing Reconquista with id 3429594
# Processing Ndago with id 226600
# Processing Outjo with id 3353715
# gorno-chuyskiy not found
# Processing Oga with id 2343943
# mentok not found
# Processing Bystrzyca Klodzka with id 3101968
# Processing Paso de Patria with id 3430105
# doctor pedro p. pena not found
# Processing Chibombo with id 920233
# Processing Biak with id 1637001
# Processing Caxito with id 3451261
# Processing Aberdeen with id 5225857
# terenga not found
# Processing Upata with id 3625710
# Processing Tingo Maria with id 3691348
# Processing Mandera with id 187896
# Processing Daru with id 2409663
# Processing Storslett with id 777381
# Processing Kruisfontein with id 986717
# Processing Yerbogachen with id 2012956
# Processing Puerto del Rosario with id 2512186
# Processing Solhan with id 300377
# artyk not found
# Processing Villamontes with id 3901547
# Processing Abong Mbang with id 2236053
# Processing Benghazi with id 88319
# Processing North Bend with id 5742974
# Processing Zhangye with id 1785036
# Processing Leh with id 1264976
# Processing Chase with id 5006946
# Processing Los Llanos de Aridane with id 2514651
# Processing Clyde River with id 5924351
# Processing Ilulissat with id 3423146
# Processing Port-Gentil with id 2396518
# Processing Omboue with id 2396853
# Processing Maumere with id 1635815
# Processing Keelung with id 1678228
# Processing Atambua with id 1651103
# Processing Hokitika with id 2206894
# mancio lima not found
# Processing Altamont with id 6065191
# Processing Tretten with id 3134016
# Processing Gravdal with id 3147822
# kapoeta not found
# Processing Warman with id 6176226
# Processing Goderich with id 5962442
# Processing Henties Bay with id 3356832
# gollere not found
# Processing Minchinabad with id 1170398
# Processing Pak Phanang with id 1608033
# Processing Yashkul with id 468747
# Processing Roxana with id 4248546
# Processing Belaya Gora with id 2126785
# Processing Albury with id 2178174
# Processing Inirida with id 3671450
# Processing Jiuquan with id 1280957
# Processing Yar-Sale with id 1486321
# Processing Kaitangata with id 2208248
# Processing Kysyl-Syr with id 2021017
# Processing Tumpat with id 1736356
# Processing Melfort with id 6071876
# Processing Morehead with id 4301307
# Processing Pyinmana with id 1298987
# Processing Erzin with id 296852
# Processing Taoudenni with id 2450173
# maghama not found
# Processing Saint-Pierre with id 2995603
# Processing Ormara with id 1168700
# Processing Kirakira with id 2178753
# Processing Yerofey Pavlovich with id 2012938
# Processing General Roca with id 3855065
# Processing Gat with id 2249901
# Processing Rajpura with id 1258803
# Processing Dicabisagan with id 1715015
# khonuu not found
# Processing Sainte-Marie with id 6945989
# Processing Maragua with id 187733
# Processing Dhidhdhoo with id 1337612
# Processing Kez with id 550902
# Processing Ketchikan with id 5554428
# Processing Kushiro with id 2129072
# Processing Whitehorse with id 6180550
# Processing Havoysund with id 779622
# Processing Matay with id 352628
# bardiyah not found
# Processing Maldonado with id 3441894
# Processing Lipari with id 2524379
# Processing Plouzane with id 2986626
# Processing Minas Novas with id 3457152
# Processing Innisfail with id 5983430
# Processing Shima with id 1861450
# Processing Veshenskaya with id 473998
# Processing Melendugno with id 3173630
# Processing Klaksvik with id 2618795
# Processing Palmas with id 3474574
# Processing Mago with id 2123621
# Processing Belmonte with id 8010472
# Processing Anupgarh with id 1278510
# Processing Atlantic Beach with id 4146354
# Processing Lyuban with id 625721
# Processing Kieta with id 2094027
# Processing Killarney with id 2161441
# Processing Severo-Yeniseyskiy with id 1492566
# Processing Hanstholm with id 2620786
# Processing Ojinaga with id 3994469
# Processing Mercedes with id 3441684
# Processing Ulladulla with id 2145554
# Processing Tweed with id 6170799
# Processing Gamba with id 1281256
# Processing Okhotsk with id 2122605
# Processing Senekal with id 956507
# Processing Rio Gallegos with id 3838859
# Processing Wuwei with id 1803936
# Processing Kenai with id 5866063
# Processing Pa Daet with id 1608068
# Processing Newport with id 2641598
# Processing Souillac with id 3026644
# phnum penh not found
# Processing Mhlume with id 934966
# Processing Sharan with id 1120879
# Processing Antibes with id 3037456
# wulanhaote not found
# Processing Mayo with id 6068416
# Processing Aranos with id 3358666
# Processing Bull Savanna with id 3491161
# name          537
# id            537
# lat           537
# windspeed     537
# temp          537
# humidity      537
# cloudiness    537
# dtype: int64

# %%
summary_df.head()
# Out:
#            name       id    lat  windspeed   temp  humidity  cloudiness
# 0       Mataura  6201424 -46.19       3.67   6.99        97          92
# 1         Buala  2109528  -8.15       1.77  28.64        87          68
# 2  Punta Arenas  3874787 -53.16       3.10   1.00        64          20
# 3        Ixtapa  4004293  20.71       3.10  27.00        94          75
# 4     Busselton  2075265 -33.64       4.62  17.59        94          68

# %%
#for all scatter plots
def weather_scat (index,column,y_label,fig_title,outfile_name):
    """
    index determines color graph
    column - str for the column in summary_df to use for y values
    y_label - the y axis label (x_axis is latitude values)
    fig-title - the graph title
    outfile_name -  .png file for saving the graph 
    """
    
    colors=("red","blue","grey","green")
    fig,ax=plt.subplots(figsize=(7,7),facecolor="lightgrey")
    ax.set_facecolor('whitesmoke')
 #set x axis   
    x_axis=summary_df["lat"]
    ax.set_xlabel("Latitude",fontsize=12)
 #set y axis   
    y_data=summary_df[column]
    ax.set_ylabel(y_label,fontsize=12)
#plot and save to file    
    ax.grid()
    fig.suptitle(fig_title, fontsize=16)
    ax.scatter(x_axis,y_data,marker='o',facecolor=colors[index],edgecolor="black")
    plt.savefig(outfile_name)
    plt.show()
    return

# %%
#Temp vs Lat scatterplot
weather_scat(0,"temp","Temperature (celsius)","City Latitude vs. Temperature  "+today,temp_file)

# %%
#humidity vs latitude scatterplot
weather_scat(1,"humidity","Humidity(%)","City Latitude vs. Humidity "+today,humidity_file)

# %%
#cloudiness vs latitude
weather_scat(2,"cloudiness","Cloudiness (%)","City Latitude vs.Cloudiness "+today,cloud_file)

# %%
#wind speed vs latitude
weather_scat(3,"windspeed","Wind Speed (m/sec)","City Latitude vs.Wind Speed "+today,wind_file)
